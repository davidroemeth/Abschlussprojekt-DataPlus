# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 📂 Datei einlesen

# %%
df = pd.read_csv("/Users/david/Desktop/dataplus/PROJEKTWOCHE 21.05.-03.06./data/2025-05-21-washington-post-police-shootings-export.csv")

# %%
df
# Out:
#              date                          name   age gender    armed  \
# 0      2015-01-02              Lewis Lee Lembke  47.0   male      gun
# 1      2015-01-02                    Tim Elliot  53.0   male      gun
# 2      2015-01-03            John Paul Quintero  23.0   male  unarmed
# 3      2015-01-04             Kenneth Joe Brown  18.0   male      gun
# 4      2015-01-04             Michael Rodriguez  39.0   male    other
# ...           ...                           ...   ...    ...      ...
# 10425  2024-12-30                 Timothy Woods  26.0   male      gun
# 10426  2024-12-30                           NaN  38.0   male    knife
# 10427  2024-12-30  Kenneth Thaddeus Roberts Jr.  48.0   male      gun
# 10428  2024-12-31                    Moses Alik  22.0   male    knife
# 10429  2024-12-31           James Junior Holder  41.0   male      gun
#
#            race          city state  flee  body_camera  \
# 0         White         Aloha    OR   not        False
# 1         Asian       Shelton    WA   not        False
# 2      Hispanic       Wichita    KS   not        False
# 3         White       Guthrie    OK   not        False
# 4      Hispanic         Evans    CO   not        False
# ...         ...           ...   ...   ...          ...
# 10425     Black       Orlando    FL  foot        False
# 10426   Unknown    Sacramento    CA   NaN         True
# 10427     Black  Indianapolis    IN   car        False
# 10428   Unknown        Celina    OH   NaN        False
# 10429   Unknown   Chattanooga    TN   not        False
#
#        signs_of_mental_illness  \
# 0                        False
# 1                         True
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 10425                    False
# 10426                     True
# 10427                    False
# 10428                    False
# 10429                    False
#
#                              police_departments_involved
# 0                 Washington County Sheriff's Office, OR
# 1                      Mason County Sheriff's Office, WA
# 2                          Wichita Police Department, KS
# 3                            Oklahoma Highway Patrol, OK
# 4                            Evans Police Department, CO
# ...                                                  ...
# 10425                      Orlando Police Department, FL
# 10426         Sacramento County Sheriff's Department, CA
# 10427  Indianapolis Metropolitan Police Department, I...
# 10428                 Mercer County Sheriff's Office, OH
# 10429               Hamilton County Sheriff's Office, TN
#
# [10430 rows x 12 columns]

# %% [markdown]
# ### 🕒 Datum konvertieren

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %% [markdown]
# ### 📍 Jahr extrahieren für spätere Filter/Plots

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %% [markdown]
# ### 🔎 Überblick: Spalten & Datentypen

# %%
print("Spalten & Datentypen:")
print(df.dtypes)
# Out:
# Spalten & Datentypen:
# date                           datetime64[ns]
# name                                   object
# age                                   float64
# gender                                 object
# armed                                  object
# race                                   object
# city                                   object
# state                                  object
# flee                                   object
# body_camera                              bool
# signs_of_mental_illness                  bool
# police_departments_involved            object
# year                                    int32
# month                                   int32
# dtype: object

# %% [markdown]
# ### 👀 Erste fünf Zeilen

# %%
print("\nVorschau auf die Daten:")
print(df.head())
# Out:
# Vorschau auf die Daten:
#         date                name   age gender    armed      race     city  \
# 0 2015-01-02    Lewis Lee Lembke  47.0   male      gun     White    Aloha
# 1 2015-01-02          Tim Elliot  53.0   male      gun     Asian  Shelton
# 2 2015-01-03  John Paul Quintero  23.0   male  unarmed  Hispanic  Wichita
# 3 2015-01-04   Kenneth Joe Brown  18.0   male      gun     White  Guthrie
# 4 2015-01-04   Michael Rodriguez  39.0   male    other  Hispanic    Evans
#
#   state flee  body_camera  signs_of_mental_illness  \
# 0    OR  not        False                    False
# 1    WA  not        False                     True
# 2    KS  not        False                    False
# 3    OK  not        False                    False
# 4    CO  not        False                    False
#
#               police_departments_involved  year  month
# 0  Washington County Sheriff's Office, OR  2015      1
# 1       Mason County Sheriff's Office, WA  2015      1
# 2           Wichita Police Department, KS  2015      1
# 3             Oklahoma Highway Patrol, OK  2015      1
# 4             Evans Police Department, CO  2015      1

# %% [markdown]
# ### 🧼 Anzahl fehlender Werte pro Spalte

# %%
print("\nAnzahl fehlender Werte:")
print(df.isnull().sum())
# Out:
# Anzahl fehlender Werte:
# date                              0
# name                            318
# age                             372
# gender                           20
# armed                           211
# race                              0
# city                             74
# state                             0
# flee                           1493
# body_camera                       0
# signs_of_mental_illness           0
# police_departments_involved       1
# year                              0
# month                             0
# dtype: int64

# %% [markdown]
# ### 🏷️ Einzigartige Werte in wichtigen Spalten checken

# %%
print("\nEthnien:", df['race'].unique())
print("Bodycam:", df['body_camera'].unique())
print("Bewaffnet:", df['armed'].unique())
print("Mentale Störung:", df['signs_of_mental_illness'].unique())
print("Fluchtverhalten:", df['flee'].unique())
# Out:
# Ethnien: ['White' 'Asian' 'Hispanic' 'Black' 'Other' 'Unknown' 'Native American'
#  'White,Black,Native American' 'Native American,Hispanic' 'White,Hispanic'
#  'Black,Hispanic' 'White,Black' 'White,Asian']
# Bodycam: [False  True]
# Bewaffnet: ['gun' 'unarmed' 'other' 'replica' 'knife' 'blunt_object' nan 'vehicle'
#  'undetermined' 'other,gun' 'unknown' 'blunt_object,blunt_object'
#  'gun,knife' 'knife,blunt_object' 'vehicle,gun' 'gun,vehicle'
#  'replica,vehicle' 'blunt_object,knife' 'knife,vehicle'
#  'vehicle,knife,other' 'knife,knife' 'replica,knife'
#  'other,blunt_object,knife' 'other,knife' 'vehicle,knife' 'gun,other'
#  'blunt_object,other' 'knife,replica' 'knife,unknown'
#  'replica,blunt_object' 'blunt_object,gun']
# Mentale Störung: [False  True]
# Fluchtverhalten: ['not' 'car' 'foot' 'other' nan]

# %% [markdown]
# ### "Unknown" bei Ethnie entfernen

# %%
df_clean = df[df['race'] != 'Unknown']

# %% [markdown]
# ### flee-Spalte vereinheitlichen → derzeit steht  'not', aber vermutlich gemeint als "Not fleeing"

# %%
df['flee'] = df['flee'].replace({
    'not': 'Not fleeing',
    'foot': 'Fleeing - on foot',
    'car': 'Fleeing - in vehicle',
    'other': 'Fleeing - other',
    np.nan: 'Unknown'
})

# %% [markdown]
# ### Neue Spalte hinzufügen 'armed_simple' für 'armed' oder 'unarmed' zur Vereinfachung

# %%
import numpy as np

def classify_armed_status(value):
    if pd.isna(value):
        return 'unknown'
    value = str(value).lower()
    if 'unarmed' in value:
        return 'unarmed'
    elif value in ['no', 'none', 'n/a', 'unknown']:
        return 'unknown'
    else:
        return 'armed'

df['armed_simple'] = df['armed'].apply(classify_armed_status)
df
# Out:
#             date                          name   age gender    armed  \
# 0     2015-01-02              Lewis Lee Lembke  47.0   male      gun
# 1     2015-01-02                    Tim Elliot  53.0   male      gun
# 2     2015-01-03            John Paul Quintero  23.0   male  unarmed
# 3     2015-01-04             Kenneth Joe Brown  18.0   male      gun
# 4     2015-01-04             Michael Rodriguez  39.0   male    other
# ...          ...                           ...   ...    ...      ...
# 10425 2024-12-30                 Timothy Woods  26.0   male      gun
# 10426 2024-12-30                           NaN  38.0   male    knife
# 10427 2024-12-30  Kenneth Thaddeus Roberts Jr.  48.0   male      gun
# 10428 2024-12-31                    Moses Alik  22.0   male    knife
# 10429 2024-12-31           James Junior Holder  41.0   male      gun
#
#            race          city state                  flee  body_camera  \
# 0         White         Aloha    OR           Not fleeing        False
# 1         Asian       Shelton    WA           Not fleeing        False
# 2      Hispanic       Wichita    KS           Not fleeing        False
# 3         White       Guthrie    OK           Not fleeing        False
# 4      Hispanic         Evans    CO           Not fleeing        False
# ...         ...           ...   ...                   ...          ...
# 10425     Black       Orlando    FL     Fleeing - on foot        False
# 10426   Unknown    Sacramento    CA               Unknown         True
# 10427     Black  Indianapolis    IN  Fleeing - in vehicle        False
# 10428   Unknown        Celina    OH               Unknown        False
# 10429   Unknown   Chattanooga    TN           Not fleeing        False
#
#        signs_of_mental_illness  \
# 0                        False
# 1                         True
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 10425                    False
# 10426                     True
# 10427                    False
# 10428                    False
# 10429                    False
#
#                              police_departments_involved  year  month  \
# 0                 Washington County Sheriff's Office, OR  2015      1
# 1                      Mason County Sheriff's Office, WA  2015      1
# 2                          Wichita Police Department, KS  2015      1
# 3                            Oklahoma Highway Patrol, OK  2015      1
# 4                            Evans Police Department, CO  2015      1
# ...                                                  ...   ...    ...
# 10425                      Orlando Police Department, FL  2024     12
# 10426         Sacramento County Sheriff's Department, CA  2024     12
# 10427  Indianapolis Metropolitan Police Department, I...  2024     12
# 10428                 Mercer County Sheriff's Office, OH  2024     12
# 10429               Hamilton County Sheriff's Office, TN  2024     12
#
#       armed_simple
# 0            armed
# 1            armed
# 2          unarmed
# 3            armed
# 4            armed
# ...            ...
# 10425        armed
# 10426        armed
# 10427        armed
# 10428        armed
# 10429        armed
#
# [10430 rows x 15 columns]

# %% [markdown]
# ### fehlende Zeilen in armed/unarmed entfernen

# %%
df_clean = df[df['armed_simple'].isin(['armed', 'unarmed'])]
df_clean
# Out:
#             date                          name   age gender    armed  \
# 0     2015-01-02              Lewis Lee Lembke  47.0   male      gun
# 1     2015-01-02                    Tim Elliot  53.0   male      gun
# 2     2015-01-03            John Paul Quintero  23.0   male  unarmed
# 3     2015-01-04             Kenneth Joe Brown  18.0   male      gun
# 4     2015-01-04             Michael Rodriguez  39.0   male    other
# ...          ...                           ...   ...    ...      ...
# 10425 2024-12-30                 Timothy Woods  26.0   male      gun
# 10426 2024-12-30                           NaN  38.0   male    knife
# 10427 2024-12-30  Kenneth Thaddeus Roberts Jr.  48.0   male      gun
# 10428 2024-12-31                    Moses Alik  22.0   male    knife
# 10429 2024-12-31           James Junior Holder  41.0   male      gun
#
#            race          city state                  flee  body_camera  \
# 0         White         Aloha    OR           Not fleeing        False
# 1         Asian       Shelton    WA           Not fleeing        False
# 2      Hispanic       Wichita    KS           Not fleeing        False
# 3         White       Guthrie    OK           Not fleeing        False
# 4      Hispanic         Evans    CO           Not fleeing        False
# ...         ...           ...   ...                   ...          ...
# 10425     Black       Orlando    FL     Fleeing - on foot        False
# 10426   Unknown    Sacramento    CA               Unknown         True
# 10427     Black  Indianapolis    IN  Fleeing - in vehicle        False
# 10428   Unknown        Celina    OH               Unknown        False
# 10429   Unknown   Chattanooga    TN           Not fleeing        False
#
#        signs_of_mental_illness  \
# 0                        False
# 1                         True
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 10425                    False
# 10426                     True
# 10427                    False
# 10428                    False
# 10429                    False
#
#                              police_departments_involved  year  month  \
# 0                 Washington County Sheriff's Office, OR  2015      1
# 1                      Mason County Sheriff's Office, WA  2015      1
# 2                          Wichita Police Department, KS  2015      1
# 3                            Oklahoma Highway Patrol, OK  2015      1
# 4                            Evans Police Department, CO  2015      1
# ...                                                  ...   ...    ...
# 10425                      Orlando Police Department, FL  2024     12
# 10426         Sacramento County Sheriff's Department, CA  2024     12
# 10427  Indianapolis Metropolitan Police Department, I...  2024     12
# 10428                 Mercer County Sheriff's Office, OH  2024     12
# 10429               Hamilton County Sheriff's Office, TN  2024     12
#
#       armed_simple
# 0            armed
# 1            armed
# 2          unarmed
# 3            armed
# 4            armed
# ...            ...
# 10425        armed
# 10426        armed
# 10427        armed
# 10428        armed
# 10429        armed
#
# [10054 rows x 15 columns]

# %%
print("\nEthnien:", df['race'].unique())
# Out:
# Ethnien: ['White' 'Asian' 'Hispanic' 'Black' 'Other' 'Unknown' 'Native American'
#  'White,Black,Native American' 'Native American,Hispanic' 'White,Hispanic'
#  'Black,Hispanic' 'White,Black' 'White,Asian']

# %%
df_2024 = df[df['date'].dt.year == 2024]
print(df_2024)
# Out:
#             date                          name   age  gender    armed  \
# 9255  2024-01-01              Sidney Tafokitau  44.0    male      gun
# 9256  2024-01-01           Katelynn Rose Smith  29.0  female      gun
# 9257  2024-01-01       Victor Figueroa Roblero  48.0    male  unarmed
# 9258  2024-01-01           Aaron Travis Watson  35.0    male      gun
# 9259  2024-01-03              Rakim A. Tillery  35.0    male      gun
# ...          ...                           ...   ...     ...      ...
# 10425 2024-12-30                 Timothy Woods  26.0    male      gun
# 10426 2024-12-30                           NaN  38.0    male    knife
# 10427 2024-12-30  Kenneth Thaddeus Roberts Jr.  48.0    male      gun
# 10428 2024-12-31                    Moses Alik  22.0    male    knife
# 10429 2024-12-31           James Junior Holder  41.0    male      gun
#
#            race          city state                  flee  body_camera  \
# 9255      Other      Honolulu    HI           Not fleeing        False
# 9256    Unknown      Longview    WA           Not fleeing         True
# 9257   Hispanic   Spartanburg    SC       Fleeing - other        False
# 9258      White   Little Rock    AR  Fleeing - in vehicle        False
# 9259      Black        Ramapo    NY           Not fleeing        False
# ...         ...           ...   ...                   ...          ...
# 10425     Black       Orlando    FL     Fleeing - on foot        False
# 10426   Unknown    Sacramento    CA               Unknown         True
# 10427     Black  Indianapolis    IN  Fleeing - in vehicle        False
# 10428   Unknown        Celina    OH               Unknown        False
# 10429   Unknown   Chattanooga    TN           Not fleeing        False
#
#        signs_of_mental_illness  \
# 9255                     False
# 9256                     False
# 9257                     False
# 9258                     False
# 9259                     False
# ...                        ...
# 10425                    False
# 10426                     True
# 10427                    False
# 10428                    False
# 10429                    False
#
#                              police_departments_involved  year  month  \
# 9255                      Honolulu Police Department, HI  2024      1
# 9256                      Longview Police Department, WA  2024      1
# 9257   Spartanburg Methodist College Police Departmen...  2024      1
# 9258   Arkansas State Police, AR;Benton Police Depart...  2024      1
# 9259                           New York State Police, NY  2024      1
# ...                                                  ...   ...    ...
# 10425                      Orlando Police Department, FL  2024     12
# 10426         Sacramento County Sheriff's Department, CA  2024     12
# 10427  Indianapolis Metropolitan Police Department, I...  2024     12
# 10428                 Mercer County Sheriff's Office, OH  2024     12
# 10429               Hamilton County Sheriff's Office, TN  2024     12
#
#       armed_simple
# 9255         armed
# 9256         armed
# 9257       unarmed
# 9258         armed
# 9259         armed
# ...            ...
# 10425        armed
# 10426        armed
# 10427        armed
# 10428        armed
# 10429        armed
#
# [1175 rows x 15 columns]

# %%
print("\nEthnien:", df['race'].unique())
df_race_other = df[df['race'] == 'Other']
df_race_other

df_race_unknown =df[df['race'] == 'Unknown']
df_race_unknown
# Out:
# Ethnien: ['White' 'Asian' 'Hispanic' 'Black' 'Other' 'Unknown' 'Native American'
#  'White,Black,Native American' 'Native American,Hispanic' 'White,Hispanic'
#  'Black,Hispanic' 'White,Black' 'White,Asian']
#             date                  name   age gender         armed     race  \
# 58    2015-01-25      William Campbell  59.0   male           gun  Unknown
# 241   2015-03-30    John Marcell Allen  54.0   male           gun  Unknown
# 343   2015-05-07     Joseph Hilton Roy  72.0   male         knife  Unknown
# 400   2015-05-31  James Anthony Morris  40.0   male           gun  Unknown
# 420   2015-06-08         James Johnson  54.0   male           gun  Unknown
# ...          ...                   ...   ...    ...           ...      ...
# 10423 2024-12-29       Jordan Parisien  32.0   male  undetermined  Unknown
# 10424 2024-12-30           Nathan Paul  43.0   male       unknown  Unknown
# 10426 2024-12-30                   NaN  38.0   male         knife  Unknown
# 10428 2024-12-31            Moses Alik  22.0   male         knife  Unknown
# 10429 2024-12-31   James Junior Holder  41.0   male           gun  Unknown
#
#                 city state         flee  body_camera  signs_of_mental_illness  \
# 58           Winslow    NJ  Not fleeing        False                    False
# 241     Boulder City    NV  Not fleeing        False                    False
# 343    Lawrenceville    GA  Not fleeing        False                     True
# 400          Medford    OR  Not fleeing        False                     True
# 420      Beech Grove    IN  Not fleeing        False                     True
# ...              ...   ...          ...          ...                      ...
# 10423       Belcourt    ND      Unknown        False                     True
# 10424     West Point    UT      Unknown        False                     True
# 10426     Sacramento    CA      Unknown         True                     True
# 10428         Celina    OH      Unknown        False                    False
# 10429    Chattanooga    TN  Not fleeing        False                    False
#
#                       police_departments_involved  year  month armed_simple
# 58                  Winslow Police Department, NJ  2015      1        armed
# 241            Boulder City Police Department, NV  2015      3        armed
# 343         Gwinnett County Police Department, GA  2015      5        armed
# 400                 Medford Police Department, OR  2015      5        armed
# 420             Beech Grove Police Department, IN  2015      6        armed
# ...                                           ...   ...    ...          ...
# 10423                Bureau of Indian Affairs, ND  2024     12        armed
# 10424               Clinton Police Department, UT  2024     12      unknown
# 10426  Sacramento County Sheriff's Department, CA  2024     12        armed
# 10428          Mercer County Sheriff's Office, OH  2024     12        armed
# 10429        Hamilton County Sheriff's Office, TN  2024     12        armed
#
# [1192 rows x 15 columns]

# %%
df_clean
df_clean.to_excel("output.xlsx")

# %%
df_clean = df[df['gender'] != 'Unknown']
df_clean
# Out:
#             date                          name   age gender    armed  \
# 0     2015-01-02              Lewis Lee Lembke  47.0   male      gun
# 1     2015-01-02                    Tim Elliot  53.0   male      gun
# 2     2015-01-03            John Paul Quintero  23.0   male  unarmed
# 3     2015-01-04             Kenneth Joe Brown  18.0   male      gun
# 4     2015-01-04             Michael Rodriguez  39.0   male    other
# ...          ...                           ...   ...    ...      ...
# 10425 2024-12-30                 Timothy Woods  26.0   male      gun
# 10426 2024-12-30                           NaN  38.0   male    knife
# 10427 2024-12-30  Kenneth Thaddeus Roberts Jr.  48.0   male      gun
# 10428 2024-12-31                    Moses Alik  22.0   male    knife
# 10429 2024-12-31           James Junior Holder  41.0   male      gun
#
#            race          city state                  flee  body_camera  \
# 0         White         Aloha    OR           Not fleeing        False
# 1         Asian       Shelton    WA           Not fleeing        False
# 2      Hispanic       Wichita    KS           Not fleeing        False
# 3         White       Guthrie    OK           Not fleeing        False
# 4      Hispanic         Evans    CO           Not fleeing        False
# ...         ...           ...   ...                   ...          ...
# 10425     Black       Orlando    FL     Fleeing - on foot        False
# 10426   Unknown    Sacramento    CA               Unknown         True
# 10427     Black  Indianapolis    IN  Fleeing - in vehicle        False
# 10428   Unknown        Celina    OH               Unknown        False
# 10429   Unknown   Chattanooga    TN           Not fleeing        False
#
#        signs_of_mental_illness  \
# 0                        False
# 1                         True
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 10425                    False
# 10426                     True
# 10427                    False
# 10428                    False
# 10429                    False
#
#                              police_departments_involved  year  month  \
# 0                 Washington County Sheriff's Office, OR  2015      1
# 1                      Mason County Sheriff's Office, WA  2015      1
# 2                          Wichita Police Department, KS  2015      1
# 3                            Oklahoma Highway Patrol, OK  2015      1
# 4                            Evans Police Department, CO  2015      1
# ...                                                  ...   ...    ...
# 10425                      Orlando Police Department, FL  2024     12
# 10426         Sacramento County Sheriff's Department, CA  2024     12
# 10427  Indianapolis Metropolitan Police Department, I...  2024     12
# 10428                 Mercer County Sheriff's Office, OH  2024     12
# 10429               Hamilton County Sheriff's Office, TN  2024     12
#
#       armed_simple
# 0            armed
# 1            armed
# 2          unarmed
# 3            armed
# 4            armed
# ...            ...
# 10425        armed
# 10426        armed
# 10427        armed
# 10428        armed
# 10429        armed
#
# [10430 rows x 15 columns]

# %%
df_clean
df_cleancurrent = df_clean.dropna()
df_cleancurrent.to_excel("output.xlsx")

# %% [markdown]
# ### Spalte 'race' weiter vereinfachen: mehr als eine Ethnie wird zu 'multi/other'

# %%
def simplify_race(value):
    if isinstance(value, str):
        value = value.strip()
        if value.lower() == "unknown" or value == "":
            return "Unknown"
        elif "," in value:
            return "Multi/Other"
        else:
            return value
    else:
        return "Unknown"

# %%
df['race_clean'] = df['race'].apply(simplify_race)

# %%
print("Fehlende Werte:", df['race_clean'].isna().sum())
print(df['race_clean'].value_counts(dropna=False))
# Out:
# Fehlende Werte: 0
# race_clean
# White              4657
# Black              2484
# Hispanic           1717
# Unknown            1192
# Asian               184
# Native American     146
# Other                37
# Multi/Other          13
# Name: count, dtype: int64

# %%
df['race_clean'] = df['race_clean'].replace({'Other': 'Multi/Other'})

# %%
df['race_clean'].value_counts()
# Out:
# race_clean
# White              4657
# Black              2484
# Hispanic           1717
# Unknown            1192
# Asian               184
# Native American     146
# Multi/Other          50
# Name: count, dtype: int64

# %% [markdown]
# ### Ditionary für Vergleiche mit Gesamtbevölkerung gemessen an Census von 2020

# %%
population_shares = {
    'White': 0.583,              # White alone
    'Black': 0.136,              # Black alone
    'Hispanic': 0.193,           # Näherung über "Some Other Race"
    'Asian': 0.063,              # Asian alone
    'Native American': 0.012,    # American Indian and Alaska Native
    'Multi/Other': 0.013,        # Mixed/Other (inkl. Pacific, multi-race)
    'Unknown': None              # Keine Vergleichszahl
}

# %%
victim_shares = df['race_clean'].value_counts(normalize=True)

print("📊 Vergleich Opferanteil vs. Bevölkerungsanteil:\n")
for group, pop_share in population_shares.items():
    victim_share = victim_shares.get(group, 0)
    if pop_share is not None:
        ratio = victim_share / pop_share
        print(f"{group:<16} | Opfer: {victim_share:.1%} | Bevölkerung: {pop_share:.1%} → Verhältnis: {ratio:.2f}")
    else:
        print(f"{group:<16} | Opfer: {victim_share:.1%} | Bevölkerung: —      → Verhältnis: n/a")
# Out:
# 📊 Vergleich Opferanteil vs. Bevölkerungsanteil:
#
# White            | Opfer: 44.7% | Bevölkerung: 58.3% → Verhältnis: 0.77
# Black            | Opfer: 23.8% | Bevölkerung: 13.6% → Verhältnis: 1.75
# Hispanic         | Opfer: 16.5% | Bevölkerung: 19.3% → Verhältnis: 0.85
# Asian            | Opfer: 1.8% | Bevölkerung: 6.3% → Verhältnis: 0.28
# Native American  | Opfer: 1.4% | Bevölkerung: 1.2% → Verhältnis: 1.17
# Multi/Other      | Opfer: 0.5% | Bevölkerung: 1.3% → Verhältnis: 0.37
# Unknown          | Opfer: 11.4% | Bevölkerung: —      → Verhältnis: n/a

# %%
victim_shares
# Out:
# race_clean
# White              0.446500
# Black              0.238159
# Hispanic           0.164621
# Unknown            0.114286
# Asian              0.017641
# Native American    0.013998
# Multi/Other        0.004794
# Name: proportion, dtype: float64

# %%
df
# Out:
#             date                          name   age gender    armed  \
# 0     2015-01-02              Lewis Lee Lembke  47.0   male      gun
# 1     2015-01-02                    Tim Elliot  53.0   male      gun
# 2     2015-01-03            John Paul Quintero  23.0   male  unarmed
# 3     2015-01-04             Kenneth Joe Brown  18.0   male      gun
# 4     2015-01-04             Michael Rodriguez  39.0   male    other
# ...          ...                           ...   ...    ...      ...
# 10425 2024-12-30                 Timothy Woods  26.0   male      gun
# 10426 2024-12-30                           NaN  38.0   male    knife
# 10427 2024-12-30  Kenneth Thaddeus Roberts Jr.  48.0   male      gun
# 10428 2024-12-31                    Moses Alik  22.0   male    knife
# 10429 2024-12-31           James Junior Holder  41.0   male      gun
#
#            race          city state                  flee  body_camera  \
# 0         White         Aloha    OR           Not fleeing        False
# 1         Asian       Shelton    WA           Not fleeing        False
# 2      Hispanic       Wichita    KS           Not fleeing        False
# 3         White       Guthrie    OK           Not fleeing        False
# 4      Hispanic         Evans    CO           Not fleeing        False
# ...         ...           ...   ...                   ...          ...
# 10425     Black       Orlando    FL     Fleeing - on foot        False
# 10426   Unknown    Sacramento    CA               Unknown         True
# 10427     Black  Indianapolis    IN  Fleeing - in vehicle        False
# 10428   Unknown        Celina    OH               Unknown        False
# 10429   Unknown   Chattanooga    TN           Not fleeing        False
#
#        signs_of_mental_illness  \
# 0                        False
# 1                         True
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 10425                    False
# 10426                     True
# 10427                    False
# 10428                    False
# 10429                    False
#
#                              police_departments_involved  year  month  \
# 0                 Washington County Sheriff's Office, OR  2015      1
# 1                      Mason County Sheriff's Office, WA  2015      1
# 2                          Wichita Police Department, KS  2015      1
# 3                            Oklahoma Highway Patrol, OK  2015      1
# 4                            Evans Police Department, CO  2015      1
# ...                                                  ...   ...    ...
# 10425                      Orlando Police Department, FL  2024     12
# 10426         Sacramento County Sheriff's Department, CA  2024     12
# 10427  Indianapolis Metropolitan Police Department, I...  2024     12
# 10428                 Mercer County Sheriff's Office, OH  2024     12
# 10429               Hamilton County Sheriff's Office, TN  2024     12
#
#       armed_simple race_clean
# 0            armed      White
# 1            armed      Asian
# 2          unarmed   Hispanic
# 3            armed      White
# 4            armed   Hispanic
# ...            ...        ...
# 10425        armed      Black
# 10426        armed    Unknown
# 10427        armed      Black
# 10428        armed    Unknown
# 10429        armed    Unknown
#
# [10430 rows x 16 columns]

# %%
df.to_csv("Dataset Police Violence.csv")
